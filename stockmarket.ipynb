# %% [markdown]
# <a href="https://colab.research.google.com/github/renuka5C3/Stock-market-Prediction/blob/main/stockmarket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
import io


training_data = pd.read_csv('/content/Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#      <input type="file" id="files-208a3c5c-9251-48b7-b319-849e5add1cdc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-208a3c5c-9251-48b7-b319-849e5add1cdc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Google_Stock_Price_Train.csv to Google_Stock_Price_Train.csv
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler(feature_range = (0, 1))
training_data = mm.fit_transform(training_data)

# %%
# Getting the inputs and outputs

x_train = training_data[0:1257]
y_train = training_data[1:1258]

print(x_train.shape)
print(y_train.shape)
# Out:
# (1257, 1)
# (1257, 1)

# %%
x_train = np.reshape(x_train, (1257, 1, 1))

print(x_train.shape)
# Out:
# (1257, 1, 1)

# %%
# importing the keras libraries and packages

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# initializing the model
model = Sequential()

# adding the input layer and the LSTM layer
model.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))

# adding the output layer
model.add(Dense(units = 1))

# compiling the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# fitting the RNN to the training data
model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 1s 2ms/step - loss: 0.0852
# Epoch 2/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0811
# Epoch 3/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0774
# Epoch 4/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0737
# Epoch 5/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0701
# Epoch 6/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0667
# Epoch 7/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0632
# Epoch 8/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0598
# Epoch 9/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0565
# Epoch 10/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0533
# Epoch 11/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0499
# Epoch 12/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0467
# Epoch 13/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0436
# Epoch 14/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0406
# Epoch 15/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0375
# Epoch 16/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0346
# Epoch 17/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0318
# Epoch 18/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0290
# Epoch 19/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 20/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0239
# Epoch 21/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0215
# Epoch 22/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0193
# Epoch 23/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0171
# Epoch 24/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0152
# Epoch 25/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 26/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 27/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 28/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0087
# Epoch 29/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 30/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 31/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 32/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 33/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 34/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 35/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 36/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 37/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 38/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 39/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 40/200
# 40/40 [==============================] - 0s 2ms/step - loss: 9.6419e-04
# Epoch 41/200
# 40/40 [==============================] - 0s 2ms/step - loss: 8.0121e-04
# Epoch 42/200
# 40/40 [==============================] - 0s 2ms/step - loss: 6.7173e-04
# Epoch 43/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.6958e-04
# Epoch 44/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.9371e-04
# Epoch 45/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.3073e-04
# Epoch 46/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8803e-04
# Epoch 47/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4967e-04
# Epoch 48/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2682e-04
# Epoch 49/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0709e-04
# Epoch 50/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9397e-04
# Epoch 51/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8350e-04
# Epoch 52/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7759e-04
# Epoch 53/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7226e-04
# Epoch 54/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7071e-04
# Epoch 55/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6574e-04
# Epoch 56/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6428e-04
# Epoch 57/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6338e-04
# Epoch 58/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6237e-04
# Epoch 59/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6284e-04
# Epoch 60/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6247e-04
# Epoch 61/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6061e-04
# Epoch 62/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6051e-04
# Epoch 63/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6101e-04
# Epoch 64/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6051e-04
# Epoch 65/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5995e-04
# Epoch 66/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6076e-04
# Epoch 67/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6185e-04
# Epoch 68/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6109e-04
# Epoch 69/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6075e-04
# Epoch 70/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5972e-04
# Epoch 71/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5933e-04
# Epoch 72/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5981e-04
# Epoch 73/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5945e-04
# Epoch 74/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5935e-04
# Epoch 75/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5920e-04
# Epoch 76/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5864e-04
# Epoch 77/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5870e-04
# Epoch 78/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5876e-04
# Epoch 79/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5893e-04
# Epoch 80/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5803e-04
# Epoch 81/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5853e-04
# Epoch 82/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5972e-04
# Epoch 83/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5799e-04
# Epoch 84/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5845e-04
# Epoch 85/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5593e-04
# Epoch 86/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5920e-04
# Epoch 87/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5861e-04
# Epoch 88/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5811e-04
# Epoch 89/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5822e-04
# Epoch 90/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5820e-04
# Epoch 91/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5747e-04
# Epoch 92/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5679e-04
# Epoch 93/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5823e-04
# Epoch 94/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5759e-04
# Epoch 95/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5813e-04
# Epoch 96/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5712e-04
# Epoch 97/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5845e-04
# Epoch 98/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5893e-04
# Epoch 99/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5969e-04
# Epoch 100/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5699e-04
# Epoch 101/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5599e-04
# Epoch 102/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5656e-04
# Epoch 103/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5684e-04
# Epoch 104/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5626e-04
# Epoch 105/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5515e-04
# Epoch 106/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5744e-04
# Epoch 107/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5740e-04
# Epoch 108/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5678e-04
# Epoch 109/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5751e-04
# Epoch 110/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5537e-04
# Epoch 111/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5838e-04
# Epoch 112/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5678e-04
# Epoch 113/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5591e-04
# Epoch 114/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5796e-04
# Epoch 115/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6315e-04
# Epoch 116/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5306e-04
# Epoch 117/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5870e-04
# Epoch 118/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5371e-04
# Epoch 119/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5394e-04
# Epoch 120/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5363e-04
# Epoch 121/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5440e-04
# Epoch 122/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5669e-04
# Epoch 123/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5731e-04
# Epoch 124/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5389e-04
# Epoch 125/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5667e-04
# Epoch 126/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5315e-04
# Epoch 127/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5215e-04
# Epoch 128/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5428e-04
# Epoch 129/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5262e-04
# Epoch 130/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5593e-04
# Epoch 131/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5558e-04
# Epoch 132/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5448e-04
# Epoch 133/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5513e-04
# Epoch 134/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5176e-04
# Epoch 135/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5274e-04
# Epoch 136/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5458e-04
# Epoch 137/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5297e-04
# Epoch 138/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5535e-04
# Epoch 139/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5216e-04
# Epoch 140/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5416e-04
# Epoch 141/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5393e-04
# Epoch 142/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5309e-04
# Epoch 143/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5606e-04
# Epoch 144/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5093e-04
# Epoch 145/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5333e-04
# Epoch 146/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5429e-04
# Epoch 147/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5133e-04
# Epoch 148/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5158e-04
# Epoch 149/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5222e-04
# Epoch 150/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5196e-04
# Epoch 151/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5411e-04
# Epoch 152/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5187e-04
# Epoch 153/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.4873e-04
# Epoch 154/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5102e-04
# Epoch 155/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5068e-04
# Epoch 156/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5174e-04
# Epoch 157/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5519e-04
# Epoch 158/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5080e-04
# Epoch 159/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5218e-04
# Epoch 160/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.5815e-04
# Epoch 161/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5963e-04
# Epoch 162/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5261e-04
# Epoch 163/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5447e-04
# Epoch 164/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5685e-04
# Epoch 165/200
# 40/40 [==============================] - 0s 8ms/step - loss: 2.5727e-04
# Epoch 166/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.6247e-04
# Epoch 167/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5652e-04
# Epoch 168/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.4970e-04
# Epoch 169/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5423e-04
# Epoch 170/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5256e-04
# Epoch 171/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5325e-04
# Epoch 172/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5683e-04
# Epoch 173/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5378e-04
# Epoch 174/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5658e-04
# Epoch 175/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6383e-04
# Epoch 176/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6472e-04
# Epoch 177/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5104e-04
# Epoch 178/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5197e-04
# Epoch 179/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5323e-04
# Epoch 180/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5514e-04
# Epoch 181/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5013e-04
# Epoch 182/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.4929e-04
# Epoch 183/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5424e-04
# Epoch 184/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.4852e-04
# Epoch 185/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5252e-04
# Epoch 186/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5013e-04
# Epoch 187/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5069e-04
# Epoch 188/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5163e-04
# Epoch 189/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6389e-04
# Epoch 190/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5229e-04
# Epoch 191/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5660e-04
# Epoch 192/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5308e-04
# Epoch 193/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5272e-04
# Epoch 194/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5864e-04
# Epoch 195/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.4968e-04
# Epoch 196/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5855e-04
# Epoch 197/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.4983e-04
# Epoch 198/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5438e-04
# Epoch 199/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.4938e-04
# Epoch 200/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6045e-04

# %%
# getting the real stock of 2017 i.e., importing the test dataset
from google.colab import files
uploaded = files.upload()
import io
test_data = pd.read_csv('/content/Google_Stock_Price_Test.csv')
real_stock_price = test_data.iloc[:,1:2]
real_stock_price.head()
# Out:
#      <input type="file" id="files-319eaf6c-4050-49ef-b2f7-cd7173212dc8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-319eaf6c-4050-49ef-b2f7-cd7173212dc8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Google_Stock_Price_Test.csv to Google_Stock_Price_Test.csv
#      Open
# 0  778.81
# 1  788.36
# 2  786.08
# 3  795.26
# 4  806.40

# %%
# getting the predicted stock price of 2017

inputs = real_stock_price
inputs = mm.transform(inputs)
inputs = np.reshape(inputs, (20, 1, 1))


predicted_stock_price = model.predict(inputs)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
# visualizing the results

plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# getting the real stock price of 2012 - 2016

training_data = pd.read_csv('/content/Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
predicted_stock_price = model.predict(x_train)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)
plt.plot(training_data, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
